# %%
import pandas as pd

# Load the CSV into a DataFrame
df = pd.read_csv("Motor_Vehicle_Collisions_-_Crashes_20250724.csv")
# Out:
# C:\Users\Oholg\AppData\Local\Temp\ipykernel_23504\3144125150.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Motor_Vehicle_Collisions_-_Crashes_20250724.csv")

# %%
df
# Out:
#          CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0        09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1        03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2        11/01/2023       1:29  BROOKLYN  11230.0  40.621790 -73.970024
# 3        06/29/2022       6:55       NaN      NaN        NaN        NaN
# 4        09/21/2022      13:21       NaN      NaN        NaN        NaN
# ...             ...        ...       ...      ...        ...        ...
# 2192848  07/20/2025      16:50       NaN      NaN  40.798256 -73.924020
# 2192849  07/19/2025       8:55     BRONX  10454.0  40.807350 -73.917310
# 2192850  07/14/2025      11:10    QUEENS  11423.0  40.717533 -73.773155
# 2192851  07/19/2025      15:55       NaN      NaN  40.741210 -73.842770
# 2192852  07/20/2025       2:55    QUEENS  11420.0  40.671616 -73.820790
#
#                         LOCATION           ON STREET NAME CROSS STREET NAME  \
# ...

# %%
# Create a DataFrame of columns and data types
df_types = pd.DataFrame({
    'Column Name': df.columns,
    'Data Type': df.dtypes.values
})

df_types
# Out:
#                       Column Name Data Type
# 0                      CRASH DATE    object
# 1                      CRASH TIME    object
# 2                         BOROUGH    object
# 3                        ZIP CODE    object
# 4                        LATITUDE   float64
# 5                       LONGITUDE   float64
# 6                        LOCATION    object
# 7                  ON STREET NAME    object
# 8               CROSS STREET NAME    object
# 9                 OFF STREET NAME    object
# 10      NUMBER OF PERSONS INJURED   float64
# 11       NUMBER OF PERSONS KILLED   float64
# 12  NUMBER OF PEDESTRIANS INJURED     int64
# 13   NUMBER OF PEDESTRIANS KILLED     int64
# 14      NUMBER OF CYCLIST INJURED     int64
# 15       NUMBER OF CYCLIST KILLED     int64
# 16     NUMBER OF MOTORIST INJURED     int64
# 17      NUMBER OF MOTORIST KILLED     int64
# 18  CONTRIBUTING FACTOR VEHICLE 1    object
# 19  CONTRIBUTING FACTOR VEHICLE 2    object
# ...

# %%
# Read the CSV file into pandas DataFrame
df = pd.read_csv("Motor_Vehicle_Collisions_-_Crashes_20250724.csv")

# Display the columns and their data types
print(df.info())
# Out:
# C:\Users\Oholg\AppData\Local\Temp\ipykernel_23504\2899189974.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Motor_Vehicle_Collisions_-_Crashes_20250724.csv")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2192853 entries, 0 to 2192852
# Data columns (total 29 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   CRASH DATE                     object
#  1   CRASH TIME                     object
#  2   BOROUGH                        object
#  3   ZIP CODE                       object
#  4   LATITUDE                       float64
#  5   LONGITUDE                      float64
#  6   LOCATION                       object
#  7   ON STREET NAME                 object
#  8   CROSS STREET NAME              object
#  9   OFF STREET NAME                object
#  10  NUMBER OF PERSONS INJURED      float64
#  11  NUMBER OF PERSONS KILLED       float64
# ...

# %%
import numpy as np  # Importing numpy

# Convert CRASH DATE to datetime
df['CRASH DATE'] = pd.to_datetime(df['CRASH DATE'], errors='coerce')

# Convert CRASH TIME to datetime (hours:minutes)
df['CRASH TIME'] = pd.to_datetime(df['CRASH TIME'], format='%H:%M', errors='coerce').dt.time

# Create a temporary datetime column from CRASH TIME to extract hours
crash_time_obj = pd.to_datetime(df['CRASH TIME'].astype(str), format='%H:%M', errors='coerce')

# Add DAY_NIGHT column: Day = 6:00 - 18:00, Night = Otherwise
df['DAY_NIGHT'] = np.where(crash_time_obj.dt.hour.between(6, 18), 'Day', 'Night')

# Check for missing values (optional - for inspection)
print(df.isnull().sum().sort_values(ascending=False))

# Fill missing BOROUGH with "UNKNOWN"
df['BOROUGH'] = df['BOROUGH'].fillna('UNKNOWN')

# Convert ZIP CODE to numeric (set errors='coerce' to handle invalid values)
df['ZIP CODE'] = pd.to_numeric(df['ZIP CODE'], errors='coerce')
# Out:
# CRASH TIME                       2192853
# VEHICLE TYPE CODE 5              2183265
# CONTRIBUTING FACTOR VEHICLE 5    2182957
# VEHICLE TYPE CODE 4              2158009
# CONTRIBUTING FACTOR VEHICLE 4    2156711
# VEHICLE TYPE CODE 3              2040471
# CONTRIBUTING FACTOR VEHICLE 3    2034373
# OFF STREET NAME                  1810109
# CROSS STREET NAME                 837282
# ZIP CODE                          675143
# BOROUGH                           674870
# ON STREET NAME                    475118
# VEHICLE TYPE CODE 2               436248
# CONTRIBUTING FACTOR VEHICLE 2     349869
# LONGITUDE                         240124
# LOCATION                          240124
# LATITUDE                          240124
# VEHICLE TYPE CODE 1                15697
# CONTRIBUTING FACTOR VEHICLE 1       7643
# NUMBER OF PERSONS KILLED              31
# NUMBER OF PERSONS INJURED             18
# CRASH DATE                             0
# NUMBER OF PEDESTRIANS KILLED           0
# ...

# %%
df
# Out:
#         CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0       2021-09-11        NaT   UNKNOWN       NaN        NaN        NaN
# 1       2022-03-26        NaT   UNKNOWN       NaN        NaN        NaN
# 2       2023-11-01        NaT  BROOKLYN   11230.0  40.621790 -73.970024
# 3       2022-06-29        NaT   UNKNOWN       NaN        NaN        NaN
# 4       2022-09-21        NaT   UNKNOWN       NaN        NaN        NaN
# ...            ...        ...       ...       ...        ...        ...
# 2192848 2025-07-20        NaT   UNKNOWN       NaN  40.798256 -73.924020
# 2192849 2025-07-19        NaT     BRONX   10454.0  40.807350 -73.917310
# 2192850 2025-07-14        NaT    QUEENS   11423.0  40.717533 -73.773155
# 2192851 2025-07-19        NaT   UNKNOWN       NaN  40.741210 -73.842770
# 2192852 2025-07-20        NaT    QUEENS   11420.0  40.671616 -73.820790
#
#                         LOCATION           ON STREET NAME CROSS STREET NAME  \
# ...

# %%
import numpy as np  # numpy is imported

# Convert CRASH DATE to datetime
df['CRASH DATE'] = pd.to_datetime(df['CRASH DATE'], errors='coerce')

# Convert CRASH TIME to datetime (hours:minutes)
df['CRASH TIME'] = pd.to_datetime(df['CRASH TIME'], format='%H:%M', errors='coerce').dt.time

# Create a temporary datetime column from CRASH TIME for hour extraction
crash_time_obj = pd.to_datetime(df['CRASH TIME'].astype(str), format='%H:%M', errors='coerce')

# Add YEAR and MONTH columns
df['YEAR'] = df['CRASH DATE'].dt.year
df['MONTH'] = df['CRASH DATE'].dt.month

# Add HOUR column
df['HOUR'] = crash_time_obj.dt.hour

# Add DAY_NIGHT column: Day = 6:00 - 18:00, Night = Otherwise
df['DAY_NIGHT'] = np.where(df['HOUR'].between(6, 18), 'Day', 'Night')

# Add WEEKDAY column (e.g., Monday, Tuesday)
df['WEEKDAY'] = df['CRASH DATE'].dt.day_name()

# Add WEEKEND column (True if Saturday or Sunday, else False)
df['WEEKEND'] = df['WEEKDAY'].isin(['Saturday', 'Sunday'])

# Check the new columns
print(df[['CRASH DATE', 'CRASH TIME', 'YEAR', 'MONTH', 'HOUR', 'DAY_NIGHT', 'WEEKDAY', 'WEEKEND']].head())
# Out:
#   CRASH DATE CRASH TIME  YEAR  MONTH  HOUR DAY_NIGHT    WEEKDAY  WEEKEND
# 0 2021-09-11        NaT  2021      9   NaN     Night   Saturday     True
# 1 2022-03-26        NaT  2022      3   NaN     Night   Saturday     True
# 2 2023-11-01        NaT  2023     11   NaN     Night  Wednesday    False
# 3 2022-06-29        NaT  2022      6   NaN     Night  Wednesday    False
# 4 2022-09-21        NaT  2022      9   NaN     Night  Wednesday    False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2192853 entries, 0 to 2192852
# Data columns (total 35 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   CRASH DATE                     datetime64[ns]
#  1   CRASH TIME                     datetime64[ns]
#  2   BOROUGH                        object
#  3   ZIP CODE                       float64
#  4   LATITUDE                       float64
#  5   LONGITUDE                      float64
#  6   LOCATION                       object
#  7   ON STREET NAME                 object
#  8   CROSS STREET NAME              object
#  9   OFF STREET NAME                object
#  10  NUMBER OF PERSONS INJURED      float64
#  11  NUMBER OF PERSONS KILLED       float64
#  12  NUMBER OF PEDESTRIANS INJURED  int64
#  13  NUMBER OF PEDESTRIANS KILLED   int64
#  14  NUMBER OF CYCLIST INJURED      int64
#  15  NUMBER OF CYCLIST KILLED       int64
#  16  NUMBER OF MOTORIST INJURED     int64
# ...

# %%
# Drop unwanted vehicle type and contributing factor columns
df = df.drop([
    'VEHICLE TYPE CODE 3',
    'VEHICLE TYPE CODE 4',
    'VEHICLE TYPE CODE 5',
    'CONTRIBUTING FACTOR VEHICLE 3',
    'CONTRIBUTING FACTOR VEHICLE 4',
    'CONTRIBUTING FACTOR VEHICLE 5'
], axis=1)

# %%
df
# Out:
#         CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0       2021-09-11        NaT   UNKNOWN       NaN        NaN        NaN
# 1       2022-03-26        NaT   UNKNOWN       NaN        NaN        NaN
# 2       2023-11-01        NaT  BROOKLYN   11230.0  40.621790 -73.970024
# 3       2022-06-29        NaT   UNKNOWN       NaN        NaN        NaN
# 4       2022-09-21        NaT   UNKNOWN       NaN        NaN        NaN
# ...            ...        ...       ...       ...        ...        ...
# 2192848 2025-07-20        NaT   UNKNOWN       NaN  40.798256 -73.924020
# 2192849 2025-07-19        NaT     BRONX   10454.0  40.807350 -73.917310
# 2192850 2025-07-14        NaT    QUEENS   11423.0  40.717533 -73.773155
# 2192851 2025-07-19        NaT   UNKNOWN       NaN  40.741210 -73.842770
# 2192852 2025-07-20        NaT    QUEENS   11420.0  40.671616 -73.820790
#
#                         LOCATION           ON STREET NAME CROSS STREET NAME  \
# ...

# %%
# Remove duplicate rows
df = df.drop_duplicates()

# Check the new shape of the DataFrame
print(f"DataFrame now has {df.shape[0]} rows and {df.shape[1]} columns after removing duplicates.")
# Out:
# DataFrame now has 2192853 rows and 29 columns after removing duplicates.

# %%
df
# Out:
#         CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0       2021-09-11        NaT   UNKNOWN       NaN        NaN        NaN
# 1       2022-03-26        NaT   UNKNOWN       NaN        NaN        NaN
# 2       2023-11-01        NaT  BROOKLYN   11230.0  40.621790 -73.970024
# 3       2022-06-29        NaT   UNKNOWN       NaN        NaN        NaN
# 4       2022-09-21        NaT   UNKNOWN       NaN        NaN        NaN
# ...            ...        ...       ...       ...        ...        ...
# 2192848 2025-07-20        NaT   UNKNOWN       NaN  40.798256 -73.924020
# 2192849 2025-07-19        NaT     BRONX   10454.0  40.807350 -73.917310
# 2192850 2025-07-14        NaT    QUEENS   11423.0  40.717533 -73.773155
# 2192851 2025-07-19        NaT   UNKNOWN       NaN  40.741210 -73.842770
# 2192852 2025-07-20        NaT    QUEENS   11420.0  40.671616 -73.820790
#
#                         LOCATION           ON STREET NAME CROSS STREET NAME  \
# ...

# %%
# Display all columns and values of the first record
print(df.iloc[0])
# Out:
# CRASH DATE                                2021-09-11 00:00:00
# CRASH TIME                                                NaT
# BOROUGH                                               UNKNOWN
# ZIP CODE                                                  NaN
# LATITUDE                                                  NaN
# LONGITUDE                                                 NaN
# LOCATION                                                  NaN
# ON STREET NAME                          WHITESTONE EXPRESSWAY
# CROSS STREET NAME                                   20 AVENUE
# OFF STREET NAME                                           NaN
# NUMBER OF PERSONS INJURED                                 2.0
# NUMBER OF PERSONS KILLED                                  0.0
# NUMBER OF PEDESTRIANS INJURED                               0
# NUMBER OF PEDESTRIANS KILLED                                0
# NUMBER OF CYCLIST INJURED                                   0
# ...

# %%
import matplotlib.pyplot as plt

# --- 1. CRASH VOLUME TRENDS (Year, Month, Weekday) ---
crashes_by_year = df.groupby('YEAR').size()
crashes_by_month = df.groupby('MONTH').size()
crashes_by_weekday = df.groupby('WEEKDAY').size().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
)

print("Crashes by Year:\n", crashes_by_year)
print("\nCrashes by Month:\n", crashes_by_month)
print("\nCrashes by Weekday:\n", crashes_by_weekday)

# Visualize crashes by year
crashes_by_year.plot(kind='bar', title='Crashes by Year', figsize=(6, 4))
plt.ylabel('Number of Crashes')
plt.show()

# Visualize crashes by weekday
crashes_by_weekday.plot(kind='bar', title='Crashes by Weekday', figsize=(7, 4))
plt.ylabel('Number of Crashes')
plt.show()


# --- 2. DAY VS NIGHT CRASH COMPARISON ---
day_night_counts = df['DAY_NIGHT'].value_counts()
print("\nCrashes by Day vs Night:\n", day_night_counts)

# Visualize day vs night
day_night_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, title='Day vs Night Crashes')
plt.ylabel('')
plt.show()


# --- 3. BOROUGH-LEVEL INSIGHTS ---
borough_crashes = df['BOROUGH'].value_counts()
borough_yearly = df.groupby(['BOROUGH', 'YEAR']).size().unstack(fill_value=0)

print("\nCrashes by Borough:\n", borough_crashes)
print("\nCrashes by Borough per Year:\n", borough_yearly)

# Visualize crashes by borough
borough_crashes.plot(kind='bar', title='Crashes by Borough', figsize=(6, 4))
plt.ylabel('Number of Crashes')
plt.show()


# --- 4. TOP STREETS AND INTERSECTIONS ---
top_streets = df['ON STREET NAME'].value_counts().head(10)
top_cross_streets = df['CROSS STREET NAME'].value_counts().head(10)

print("\nTop 10 Streets by Crash Count:\n", top_streets)
print("\nTop 10 Cross Streets by Crash Count:\n", top_cross_streets)
# Out:
# Crashes by Year:
#  YEAR
# 2012    100545
# 2013    203742
# 2014    206046
# 2015    217702
# 2016    229831
# 2017    231007
# 2018    231564
# 2019    211486
# 2020    112917
# 2021    110557
# 2022    103886
# 2023     96606
# 2024     91302
# 2025     45662
# dtype: int64
#
# Crashes by Month:
#  MONTH
# 1     170585
# 2     157499
# 3     176746
# 4     164310
# 5     188402
# 6     189163
# 7     196652
# 8     189948
# 9     190252
# 10    196366
# 11    185915
# 12    187015
# dtype: int64
#
# Crashes by Weekday:
#  WEEKDAY
# Monday       313048
# Tuesday      322353
# Wednesday    320152
# Thursday     327379
# Friday       349011
# Saturday     296130
# Sunday       264780
# dtype: int64
# Crashes by Day vs Night:
#  DAY_NIGHT
# Night    2192853
# Name: count, dtype: int64
# Crashes by Borough:
#  BOROUGH
# UNKNOWN          674870
# BROOKLYN         485757
# QUEENS           406939
# MANHATTAN        336855
# BRONX            224810
# STATEN ISLAND     63622
# ...

# %%
# Update DAY_NIGHT with proper handling for missing HOUR
df['DAY_NIGHT'] = np.where(
    df['HOUR'].isna(), 'Unknown',  # Mark missing times as Unknown
    np.where(df['HOUR'].between(6, 18), 'Day', 'Night')
)

# Check the updated distribution
print(df['DAY_NIGHT'].value_counts())
# Out:
# DAY_NIGHT
# Unknown    2192853
# Name: count, dtype: int64

# %%
# Re-extract CRASH TIME as datetime with hour information
df['CRASH TIME'] = pd.to_datetime(df['CRASH TIME'], format='%H:%M', errors='coerce')

# Extract hour from CRASH TIME
df['HOUR'] = df['CRASH TIME'].dt.hour

# Update DAY_NIGHT again
df['DAY_NIGHT'] = np.where(
    df['HOUR'].isna(), 'Unknown',
    np.where(df['HOUR'].between(6, 18), 'Day', 'Night')
)

# Check updated counts
print(df['DAY_NIGHT'].value_counts())
# Out:
# DAY_NIGHT
# Unknown    2192853
# Name: count, dtype: int64

# %%
print(df['CRASH TIME'].dropna().unique()[:20])
# Out:
# <DatetimeArray>
# []
# Length: 0, dtype: datetime64[ns]

# %%
print(df['CRASH TIME'].head(20))
# Out:
# 0    NaT
# 1    NaT
# 2    NaT
# 3    NaT
# 4    NaT
# 5    NaT
# 6    NaT
# 7    NaT
# 8    NaT
# 9    NaT
# 10   NaT
# 11   NaT
# 12   NaT
# 13   NaT
# 14   NaT
# 15   NaT
# 16   NaT
# 17   NaT
# 18   NaT
# 19   NaT
# Name: CRASH TIME, dtype: datetime64[ns]

# %%
# Reload CRASH TIME from the CSV (only this column)
df['CRASH TIME'] = pd.read_csv("Motor_Vehicle_Collisions_-_Crashes_20250724.csv", usecols=['CRASH TIME'])['CRASH TIME']

# Parse the CRASH TIME flexibly
df['CRASH TIME'] = pd.to_datetime(df['CRASH TIME'], errors='coerce', format=None)

# Extract hour
df['HOUR'] = df['CRASH TIME'].dt.hour

# Rebuild DAY_NIGHT
df['DAY_NIGHT'] = np.where(
    df['HOUR'].isna(), 'Unknown',
    np.where(df['HOUR'].between(6, 18), 'Day', 'Night')
)

print(df['DAY_NIGHT'].value_counts())
# Out:
# C:\Users\Oholg\AppData\Local\Temp\ipykernel_23504\394988597.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['CRASH TIME'] = pd.to_datetime(df['CRASH TIME'], errors='coerce', format=None)
# DAY_NIGHT
# Day      1545125
# Night     647728
# Name: count, dtype: int64

# %%
import numpy as np

# --- DATE & TIME PROCESSING ---
# Ensure CRASH DATE is in datetime format
df['CRASH DATE'] = pd.to_datetime(df['CRASH DATE'], errors='coerce')

# Reload and parse CRASH TIME flexibly to avoid parsing errors
df['CRASH TIME'] = pd.read_csv(
    "Motor_Vehicle_Collisions_-_Crashes_20250724.csv", 
    usecols=['CRASH TIME']
)['CRASH TIME']

# Convert CRASH TIME to datetime.time, extracting hour for analysis
df['CRASH TIME'] = pd.to_datetime(df['CRASH TIME'], errors='coerce', format=None)
df['HOUR'] = df['CRASH TIME'].dt.hour

# Add DAY_NIGHT classification
df['DAY_NIGHT'] = np.where(
    df['HOUR'].isna(), 'Unknown',
    np.where(df['HOUR'].between(6, 18), 'Day', 'Night')
)

# --- ADD TIME-BASED COLUMNS ---
df['YEAR'] = df['CRASH DATE'].dt.year
df['MONTH'] = df['CRASH DATE'].dt.month
df['WEEKDAY'] = df['CRASH DATE'].dt.day_name()
df['WEEKEND'] = df['WEEKDAY'].isin(['Saturday', 'Sunday'])

# --- OPTIONAL DATA CLEANING ---
# Fill missing BOROUGH with "UNKNOWN"
df['BOROUGH'] = df['BOROUGH'].fillna('UNKNOWN')

# Convert ZIP CODE to numeric
df['ZIP CODE'] = pd.to_numeric(df['ZIP CODE'], errors='coerce')

# Drop duplicates
df = df.drop_duplicates()

# --- CHECK RESULTS ---
print(df[['CRASH DATE', 'CRASH TIME', 'HOUR', 'DAY_NIGHT', 'YEAR', 'MONTH', 'WEEKDAY', 'WEEKEND']].head())
print("\nDAY_NIGHT breakdown:\n", df['DAY_NIGHT'].value_counts())
# Out:
# C:\Users\Oholg\AppData\Local\Temp\ipykernel_23504\227685599.py:14: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['CRASH TIME'] = pd.to_datetime(df['CRASH TIME'], errors='coerce', format=None)
#   CRASH DATE          CRASH TIME  HOUR DAY_NIGHT  YEAR  MONTH    WEEKDAY  \
# 0 2021-09-11 2025-07-24 02:39:00     2     Night  2021      9   Saturday
# 1 2022-03-26 2025-07-24 11:45:00    11       Day  2022      3   Saturday
# 2 2023-11-01 2025-07-24 01:29:00     1     Night  2023     11  Wednesday
# 3 2022-06-29 2025-07-24 06:55:00     6       Day  2022      6  Wednesday
# 4 2022-09-21 2025-07-24 13:21:00    13       Day  2022      9  Wednesday
#
#    WEEKEND
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
#
# DAY_NIGHT breakdown:
#  DAY_NIGHT
# Day      1545125
# Night     647728
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# --- 1. CRASH VOLUME TRENDS (Year, Month, Weekday) ---

# Count the number of crashes per year
crashes_by_year = df.groupby('YEAR').size()
print("Crashes by Year:\n", crashes_by_year)

# Count the number of crashes per month (across all years)
crashes_by_month = df.groupby('MONTH').size()
print("\nCrashes by Month:\n", crashes_by_month)

# Count the number of crashes per weekday (reordered to start with Monday)
crashes_by_weekday = df.groupby('WEEKDAY').size().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
)
print("\nCrashes by Weekday:\n", crashes_by_weekday)

# --- Visualization: Crashes by Year ---
crashes_by_year.plot(kind='bar', title='Crashes by Year', figsize=(6, 4))
plt.ylabel('Number of Crashes')
plt.show()

# --- Visualization: Crashes by Weekday ---
crashes_by_weekday.plot(kind='bar', title='Crashes by Weekday', figsize=(7, 4))
plt.ylabel('Number of Crashes')
plt.show()


# --- 2. DAY VS NIGHT CRASH COMPARISON ---

# Count crashes occurring during Day, Night, or Unknown
day_night_counts = df['DAY_NIGHT'].value_counts()
print("\nCrashes by Day vs Night:\n", day_night_counts)

# --- Visualization: Day vs Night Crashes ---
day_night_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, title='Day vs Night Crashes')
plt.ylabel('')  # Removes the y-label for cleaner pie chart
plt.show()


# --- 3. BOROUGH-LEVEL INSIGHTS ---

# Count total crashes per borough
borough_crashes = df['BOROUGH'].value_counts()
print("\nCrashes by Borough:\n", borough_crashes)

# Count crashes per borough per year (creates a table with boroughs as rows and years as columns)
borough_yearly = df.groupby(['BOROUGH', 'YEAR']).size().unstack(fill_value=0)
print("\nCrashes by Borough per Year:\n", borough_yearly)

# --- Visualization: Crashes by Borough ---
borough_crashes.plot(kind='bar', title='Crashes by Borough', figsize=(6, 4))
plt.ylabel('Number of Crashes')
plt.show()


# --- 4. TOP STREETS AND INTERSECTIONS ---

# Find the top 10 streets with the most crashes
top_streets = df['ON STREET NAME'].value_counts().head(10)
print("\nTop 10 Streets by Crash Count:\n", top_streets)

# Find the top 10 cross streets with the most crashes
top_cross_streets = df['CROSS STREET NAME'].value_counts().head(10)
print("\nTop 10 Cross Streets by Crash Count:\n", top_cross_streets)
# Out:
# Crashes by Year:
#  YEAR
# 2012    100545
# 2013    203742
# 2014    206046
# 2015    217702
# 2016    229831
# 2017    231007
# 2018    231564
# 2019    211486
# 2020    112917
# 2021    110557
# 2022    103886
# 2023     96606
# 2024     91302
# 2025     45662
# dtype: int64
#
# Crashes by Month:
#  MONTH
# 1     170585
# 2     157499
# 3     176746
# 4     164310
# 5     188402
# 6     189163
# 7     196652
# 8     189948
# 9     190252
# 10    196366
# 11    185915
# 12    187015
# dtype: int64
#
# Crashes by Weekday:
#  WEEKDAY
# Monday       313048
# Tuesday      322353
# Wednesday    320152
# Thursday     327379
# Friday       349011
# Saturday     296130
# Sunday       264780
# dtype: int64
# Crashes by Day vs Night:
#  DAY_NIGHT
# Day      1545125
# Night     647728
# Name: count, dtype: int64
# Crashes by Borough:
#  BOROUGH
# UNKNOWN          674870
# BROOKLYN         485757
# QUEENS           406939
# MANHATTAN        336855
# BRONX            224810
# ...

# %%
# --- 5. INJURY & FATALITY ANALYSIS ---

# Calculate total injuries and fatalities
total_injured = df['NUMBER OF PERSONS INJURED'].sum()
total_killed = df['NUMBER OF PERSONS KILLED'].sum()

print(f"Total Persons Injured: {total_injured}")
print(f"Total Persons Killed: {total_killed}")

# Breakdown by road users (pedestrians, cyclists, motorists)
injury_breakdown = {
    'Pedestrians Injured': df['NUMBER OF PEDESTRIANS INJURED'].sum(),
    'Cyclists Injured': df['NUMBER OF CYCLIST INJURED'].sum(),
    'Motorists Injured': df['NUMBER OF MOTORIST INJURED'].sum(),
    'Pedestrians Killed': df['NUMBER OF PEDESTRIANS KILLED'].sum(),
    'Cyclists Killed': df['NUMBER OF CYCLIST KILLED'].sum(),
    'Motorists Killed': df['NUMBER OF MOTORIST KILLED'].sum(),
}

print("\nInjury and Fatality Breakdown:")
for key, value in injury_breakdown.items():
    print(f"{key}: {value}")

# --- Visualization: Total Injuries vs Fatalities ---
plt.bar(['Injured', 'Killed'], [total_injured, total_killed], color=['steelblue', 'red'])
plt.title('Total Injuries vs Fatalities')
plt.ylabel('Number of People')
plt.show()
# Out:
# Total Persons Injured: 711999.0
# Total Persons Killed: 3434.0
#
# Injury and Fatality Breakdown:
# Pedestrians Injured: 129552
# Cyclists Injured: 62607
# Motorists Injured: 510055
# Pedestrians Killed: 1703
# Cyclists Killed: 270
# Motorists Killed: 1398

# %%
# --- 6. CONTRIBUTING FACTORS ANALYSIS ---

# Combine all contributing factor columns into one Series
all_factors = pd.concat([
    df['CONTRIBUTING FACTOR VEHICLE 1'],
    df['CONTRIBUTING FACTOR VEHICLE 2']
    # You can add VEHICLE 3/4/5 if needed, but many are NaN
])

# Count the top 10 factors
top_factors = all_factors.value_counts().head(10)
print("\nTop 10 Contributing Factors:\n", top_factors)

# --- Visualization: Top Contributing Factors ---
top_factors.plot(kind='barh', title='Top 10 Contributing Factors', figsize=(7, 5), color='orange')
plt.xlabel('Number of Crashes')
plt.gca().invert_yaxis()  # Puts the highest value at the top
plt.show()
# Out:
# Top 10 Contributing Factors:
#  Unspecified                       2287245
# Driver Inattention/Distraction     543350
# Failure to Yield Right-of-Way      149110
# Following Too Closely              138188
# Other Vehicular                    101946
# Backing Unsafely                    88360
# Passing or Lane Usage Improper      76300
# Passing Too Closely                 64815
# Turning Improperly                  63036
# Fatigued/Drowsy                     58379
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Data
injured = df['NUMBER OF PERSONS INJURED'].sum()
killed = df['NUMBER OF PERSONS KILLED'].sum()

# Categories & Values
categories = ['Injured', 'Killed']
values = [injured, killed]

# Plot
plt.figure(figsize=(6, 5))
bars = plt.bar(categories, values, color=['blue', 'red'])

# Use log scale to make fatalities visible
plt.yscale('log')

# Add value labels on the bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height * 1.1, f"{int(height):,}", 
             ha='center', va='bottom', fontweight='bold')

# Title & labels
plt.title('Total Injuries vs Fatalities (Log Scale)')
plt.ylabel('Number of People (Log Scale)')

plt.tight_layout()
plt.show()

# %%
# Bar chart with log scale for Injuries vs Fatalities
injured = 711999
killed = 3434

plt.figure(figsize=(8, 6))
bars = plt.bar(['Injured', 'Killed'], [injured, killed], log=True, color=['blue', 'red'])

# Title with padding
plt.title('Total Injuries vs Fatalities (Log Scale)', pad=20)

# Y-axis label
plt.ylabel('Number of People (Log Scale)')

# Add labels on the bars with better spacing
for bar in bars:
    plt.text(
        bar.get_x() + bar.get_width() / 2, 
        bar.get_height() * 1.05,  # Position slightly above the bar
        f'{int(bar.get_height()):,}', 
        ha='center', va='bottom', fontsize=11, fontweight='bold'
    )

plt.tight_layout()
plt.show()

# %%
# ============================
# NYC Collision Data Analysis (1–5)
# Cleaned & Styled for Presentation
# ============================

import matplotlib.pyplot as plt

# --- CHART STYLING CONFIG ---
plt.style.use('default')
plt.rcParams.update({
    'figure.figsize': (8, 6),
    'axes.titlesize': 16,
    'axes.labelsize': 14,
    'xtick.labelsize': 12,
    'ytick.labelsize': 12
})

# --------------------------
# 1. Crashes by Year
# --------------------------
crashes_by_year = df['YEAR'].value_counts().sort_index()

plt.bar(crashes_by_year.index, crashes_by_year.values, color='blue')
plt.title('Crashes by Year')
plt.xlabel('Year')
plt.ylabel('Number of Crashes')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print("Crashes by Year:\n", crashes_by_year)


# --------------------------
# 2. Crashes by Month
# --------------------------
crashes_by_month = df['MONTH'].value_counts().sort_index()

plt.bar(crashes_by_month.index, crashes_by_month.values, color='blue')
plt.title('Crashes by Month')
plt.xlabel('Month')
plt.ylabel('Number of Crashes')
plt.xticks(range(1, 13))
plt.tight_layout()
plt.show()

print("Crashes by Month:\n", crashes_by_month)


# --------------------------
# 3. Crashes by Weekday
# --------------------------
crashes_by_weekday = df['WEEKDAY'].value_counts()

plt.bar(crashes_by_weekday.index, crashes_by_weekday.values, color='blue')
plt.title('Crashes by Weekday')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Crashes')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print("Crashes by Weekday:\n", crashes_by_weekday)


# --------------------------
# 4. Day vs Night Crashes
# --------------------------
day_night_counts = df['DAY_NIGHT'].value_counts()

plt.pie(day_night_counts, labels=day_night_counts.index, autopct='%1.1f%%',
        colors=['orange', 'navy'], startangle=90, textprops={'fontsize': 12})
plt.title('Day vs Night Crashes', fontsize=16)
plt.tight_layout()
plt.show()

print("Day vs Night Crashes:\n", day_night_counts)


# --------------------------
# 5. Injuries vs Fatalities
# --------------------------
total_injuries = df['NUMBER OF PERSONS INJURED'].sum()
total_killed = df['NUMBER OF PERSONS KILLED'].sum()

plt.bar(['Injured', 'Killed'], [total_injuries, total_killed],
        color=['blue', 'red'])
plt.yscale('log')  # To better visualize the large difference
plt.title('Total Injuries vs Fatalities (Log Scale)')
plt.ylabel('Number of People (Log Scale)')
for i, val in enumerate([total_injuries, total_killed]):
    plt.text(i, val, f'{int(val):,}', ha='center', va='bottom', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

print(f"Total Persons Injured: {int(total_injuries):,}")
print(f"Total Persons Killed: {int(total_killed):,}")


# --- Top 10 Contributing Factors ---
contributing_factors = df['CONTRIBUTING FACTOR VEHICLE 1'].value_counts().head(10)

plt.barh(contributing_factors.index, contributing_factors.values, color='orange')
plt.title('Top 10 Contributing Factors')
plt.xlabel('Number of Crashes')
plt.ylabel('Contributing Factor')
plt.tight_layout()
plt.show()

print("Top 10 Contributing Factors:\n", contributing_factors)
# Out:
# Crashes by Year:
#  YEAR
# 2012    100545
# 2013    203742
# 2014    206046
# 2015    217702
# 2016    229831
# 2017    231007
# 2018    231564
# 2019    211486
# 2020    112917
# 2021    110557
# 2022    103886
# 2023     96606
# 2024     91302
# 2025     45662
# Name: count, dtype: int64
# Crashes by Month:
#  MONTH
# 1     170585
# 2     157499
# 3     176746
# 4     164310
# 5     188402
# 6     189163
# 7     196652
# 8     189948
# 9     190252
# 10    196366
# 11    185915
# 12    187015
# Name: count, dtype: int64
# Crashes by Weekday:
#  WEEKDAY
# Friday       349011
# Thursday     327379
# Tuesday      322353
# Wednesday    320152
# Monday       313048
# Saturday     296130
# Sunday       264780
# Name: count, dtype: int64
# Day vs Night Crashes:
#  DAY_NIGHT
# Day      1545125
# Night     647728
# Name: count, dtype: int64
# Total Persons Injured: 711,999
# Total Persons Killed: 3,434
# Top 10 Contributing Factors:
#  CONTRIBUTING FACTOR VEHICLE 1
# ...

# %%
import matplotlib.ticker as mtick

# --- POLISHED ANALYSIS CHARTS (1–5) ---

plt.figure(figsize=(14, 20))

# 1. Crashes by Year
plt.subplot(3, 2, 1)
year_counts = df['YEAR'].value_counts().sort_index()
plt.bar(year_counts.index, year_counts.values, color='steelblue')
plt.title("Crashes by Year", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Number of Crashes", fontsize=12)
plt.xticks(rotation=45)
plt.gca().yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))  # Add commas to y-axis

# 2. Crashes by Month
plt.subplot(3, 2, 2)
month_counts = df['MONTH'].value_counts().sort_index()
plt.bar(month_counts.index, month_counts.values, color='darkorange')
plt.title("Crashes by Month", fontsize=16)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Number of Crashes", fontsize=12)
plt.xticks(month_counts.index, month_counts.index, rotation=45)
plt.gca().yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

# 3. Crashes by Weekday
plt.subplot(3, 2, 3)
weekday_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
weekday_counts = df['WEEKDAY'].value_counts().reindex(weekday_order)
plt.bar(weekday_counts.index, weekday_counts.values, color='steelblue')
plt.title("Crashes by Weekday", fontsize=16)
plt.xlabel("Weekday", fontsize=12)
plt.ylabel("Number of Crashes", fontsize=12)
plt.xticks(rotation=45)
plt.gca().yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

# 4. Crashes by Borough
plt.subplot(3, 2, 4)
borough_counts = df['BOROUGH'].value_counts()
plt.bar(borough_counts.index, borough_counts.values, color='darkorange')
plt.title("Crashes by Borough", fontsize=16)
plt.xlabel("Borough", fontsize=12)
plt.ylabel("Number of Crashes", fontsize=12)
plt.xticks(rotation=45)
plt.gca().yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

# 5. Injuries vs Fatalities (Log Scale)
plt.subplot(3, 2, 5)
injured = df['NUMBER OF PERSONS INJURED'].sum()
killed = df['NUMBER OF PERSONS KILLED'].sum()
plt.bar(['Injured', 'Killed'], [injured, killed], color=['blue', 'red'])
plt.yscale('log')
plt.title("Total Injuries vs Fatalities (Log Scale)", fontsize=16)
plt.ylabel("Number of People (Log Scale)", fontsize=12)
for i, value in enumerate([injured, killed]):
    plt.text(i, value, f'{int(value):,}', ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
# -----------------------
# ANALYSIS 6: Vehicle Type Analysis
# -----------------------

# Count the most common vehicle types (from VEHICLE TYPE CODE 1 column)
vehicle_counts = df['VEHICLE TYPE CODE 1'].value_counts().head(10)

# Plot the top 10 vehicle types involved in crashes
plt.figure(figsize=(10, 6))
vehicle_counts.plot(kind='barh', color='steelblue')
plt.title('Top 10 Vehicle Types Involved in Crashes', fontsize=16, pad=20)
plt.xlabel('Number of Crashes', fontsize=12)
plt.ylabel('Vehicle Type', fontsize=12)
plt.gca().invert_yaxis()  # Show highest count at the top
plt.tight_layout()
plt.show()

# -----------------------
# ANALYSIS 7: Top Streets with Most Crashes
# -----------------------

# Count crashes by ON STREET NAME (excluding missing values)
top_streets = df['ON STREET NAME'].dropna().value_counts().head(10)

# Plot the top 10 streets with the highest crash counts
plt.figure(figsize=(10, 6))
top_streets.plot(kind='barh', color='darkorange')
plt.title('Top 10 Streets by Crash Count', fontsize=16, pad=20)
plt.xlabel('Number of Crashes', fontsize=12)
plt.ylabel('Street Name', fontsize=12)
plt.gca().invert_yaxis()  # Show highest count at the top
plt.tight_layout()
plt.show()

# %%
# -----------------------
# ANALYSIS 8: Top Cross Streets
# -----------------------

# Count crashes by CROSS STREET NAME (excluding missing values)
top_cross_streets = df['CROSS STREET NAME'].dropna().value_counts().head(10)

# Plot the top 10 cross streets
plt.figure(figsize=(10, 6))
top_cross_streets.plot(kind='barh', color='seagreen')
plt.title('Top 10 Cross Streets by Crash Count', fontsize=16, pad=20)
plt.xlabel('Number of Crashes', fontsize=12)
plt.ylabel('Cross Street Name', fontsize=12)
plt.gca().invert_yaxis()  # Highest at the top
plt.tight_layout()
plt.show()

# %%
# Standardize CROSS STREET NAME (uppercase and remove extra spaces)
df['CROSS STREET NAME'] = df['CROSS STREET NAME'].str.upper().str.strip()

# Re-run the top 10 cross streets analysis
top_cross_streets = df['CROSS STREET NAME'].value_counts().head(10)
print(top_cross_streets)

# Plot the updated chart
plt.figure(figsize=(10, 6))
top_cross_streets.sort_values().plot(kind='barh', color='seagreen')
plt.title('Top 10 Cross Streets by Crash Count', fontsize=14)
plt.xlabel('Number of Crashes')
plt.ylabel('Cross Street Name')
plt.show()
# Out:
# CROSS STREET NAME
# 3 AVENUE            16954
# BROADWAY            16844
# 2 AVENUE            13702
# 5 AVENUE            11021
# 7 AVENUE            10215
# 8 AVENUE             9930
# 1 AVENUE             8859
# PARK AVENUE          8333
# LEXINGTON AVENUE     6813
# LINDEN BOULEVARD     6251
# Name: count, dtype: int64

# %%
# Calculate total crashes for percentage
total_crashes = df['ON STREET NAME'].value_counts().sum()

# Top 10 streets with counts
top_streets = df['ON STREET NAME'].value_counts().head(10)

# Plot with percentage labels
plt.figure(figsize=(10, 6))
bars = plt.barh(top_streets.index, top_streets.values, color='teal')

# Add percentage labels
for bar, value in zip(bars, top_streets.values):
    percentage = (value / total_crashes) * 100
    plt.text(value + 200, bar.get_y() + bar.get_height()/2,
             f'{value:,} ({percentage:.2f}%)',
             va='center', fontsize=10, fontweight='bold')

plt.xlabel('Number of Crashes')
plt.ylabel('Street Name')
plt.title('Top 10 Streets by Crash Count (with % of Total)')
plt.tight_layout()
plt.show()

# %%
# Calculate total crashes for percentage
total_cross_crashes = df['CROSS STREET NAME'].value_counts().sum()

# Top 10 cross streets with counts
top_cross_streets = df['CROSS STREET NAME'].value_counts().head(10)

# Plot with percentage labels
plt.figure(figsize=(10, 6))
bars = plt.barh(top_cross_streets.index, top_cross_streets.values, color='seagreen')

# Add percentage labels
for bar, value in zip(bars, top_cross_streets.values):
    percentage = (value / total_cross_crashes) * 100
    plt.text(value + 200, bar.get_y() + bar.get_height()/2,
             f'{value:,} ({percentage:.2f}%)',
             va='center', fontsize=10, fontweight='bold')

plt.xlabel('Number of Crashes')
plt.ylabel('Cross Street Name')
plt.title('Top 10 Cross Streets by Crash Count (with % of Total)')
plt.tight_layout()
plt.show()

# %%
# --- Step 1: Summary Table by Borough & Day/Night ---

# Group data by Borough and Day/Night
summary_table = df.groupby(['BOROUGH', 'DAY_NIGHT']).agg(
    Total_Crashes=('COLLISION_ID', 'count'),
    Total_Injuries=('NUMBER OF PERSONS INJURED', 'sum'),
    Total_Fatalities=('NUMBER OF PERSONS KILLED', 'sum')
).reset_index()

# Sort for readability
summary_table = summary_table.sort_values(by='Total_Crashes', ascending=False)

# Display the table
print(summary_table)
# Out:
#           BOROUGH DAY_NIGHT  Total_Crashes  Total_Injuries  Total_Fatalities
# 10        UNKNOWN       Day         467569        151968.0             529.0
# 2        BROOKLYN       Day         348217        109841.0             381.0
# 6          QUEENS       Day         289769         85986.0             301.0
# 4       MANHATTAN       Day         233005         47111.0             213.0
# 11        UNKNOWN     Night         207301         91929.0             844.0
# 0           BRONX       Day         159250         50544.0             141.0
# 3        BROOKLYN     Night         137540         58479.0             319.0
# 7          QUEENS     Night         117170         42206.0             272.0
# 5       MANHATTAN     Night         103850         28357.0             160.0
# 1           BRONX     Night          65560         26607.0             168.0
# 8   STATEN ISLAND       Day          47315         13618.0              64.0
# ...

# %%
# --- Step 2: Grouped Bar Chart for Borough & Day/Night ---
import matplotlib.pyplot as plt

# Pivot table for plotting
pivot_data = summary_table.pivot(index='BOROUGH', columns='DAY_NIGHT', values='Total_Crashes').fillna(0)

# Plot
pivot_data.plot(kind='bar', figsize=(10, 6), color=['skyblue', 'midnightblue'])

plt.title('Crashes by Borough (Day vs Night)', fontsize=16, fontweight='bold')
plt.xlabel('Borough', fontsize=12)
plt.ylabel('Number of Crashes', fontsize=12)
plt.legend(title='Time of Day')
plt.xticks(rotation=30, ha='right')

# Add labels on bars
for container in plt.gca().containers:
    plt.gca().bar_label(container, fmt='%d', fontsize=9, padding=3)

plt.tight_layout()
plt.show()

# %%
# --- Trend Analysis: Crashes by Year & Month ---

# 1. Crashes by Year
crashes_by_year = df['YEAR'].value_counts().sort_index()

plt.figure(figsize=(10, 5))
plt.plot(crashes_by_year.index, crashes_by_year.values,
         marker='o', color='royalblue', linewidth=2)

# Add value labels
for x, y in zip(crashes_by_year.index, crashes_by_year.values):
    plt.text(x, y + 2500, f'{y:,}', ha='center', fontsize=9, fontweight='bold')

plt.title('NYC Vehicle Collisions by Year (2012–2025)',
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Crashes', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# 2. Crashes by Month (aggregated across all years)
crashes_by_month = df['MONTH'].value_counts().sort_index()

plt.figure(figsize=(10, 5))
bars = plt.bar(crashes_by_month.index, crashes_by_month.values,
               color='darkorange', alpha=0.85)

# Add value labels
for bar, value in zip(bars, crashes_by_month.values):
    plt.text(bar.get_x() + bar.get_width()/2, value + 1500, f'{value:,}',
             ha='center', fontsize=9, fontweight='bold')

plt.title('NYC Vehicle Collisions by Month (All Years)',
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Number of Crashes', fontsize=12)
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# Group data by BOROUGH and calculate total injuries and fatalities
severity_by_borough = df.groupby('BOROUGH')[['NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED']].sum().reset_index()

# Calculate total severity (injuries + fatalities) for percentages
severity_by_borough['TOTAL'] = severity_by_borough['NUMBER OF PERSONS INJURED'] + severity_by_borough['NUMBER OF PERSONS KILLED']
total_severity = severity_by_borough['TOTAL'].sum()

# Plot stacked bar chart
fig, ax = plt.subplots(figsize=(10, 6))
bars_injuries = ax.bar(severity_by_borough['BOROUGH'],
                       severity_by_borough['NUMBER OF PERSONS INJURED'],
                       label='Injuries',
                       color='skyblue')

bars_fatalities = ax.bar(severity_by_borough['BOROUGH'],
                         severity_by_borough['NUMBER OF PERSONS KILLED'],
                         bottom=severity_by_borough['NUMBER OF PERSONS INJURED'],
                         label='Fatalities',
                         color='salmon')

# Add total values and percentages on the bars
for bar_inj, bar_fat, total in zip(bars_injuries, bars_fatalities, severity_by_borough['TOTAL']):
    percent = (total / total_severity) * 100
    ax.text(bar_inj.get_x() + bar_inj.get_width() / 2,
            bar_inj.get_height() + bar_fat.get_height() + 5000,
            f'{int(total):,} ({percent:.1f}%)',
            ha='center', va='bottom', fontsize=9, fontweight='bold')

# Formatting
ax.set_ylabel('Number of People')
ax.set_title('Crash Severity by Borough (Injuries + Fatalities, % of Total)')
ax.legend()
plt.xticks(rotation=30, ha='right')
plt.tight_layout()
plt.show()

# %%
# Recreate borough_severity DataFrame
borough_severity = df.groupby('BOROUGH').agg(
    Total_Injuries=('NUMBER OF PERSONS INJURED', 'sum'),
    Total_Fatalities=('NUMBER OF PERSONS KILLED', 'sum')
).reset_index()

# Verify the result
print(borough_severity)
# Out:
#          BOROUGH  Total_Injuries  Total_Fatalities
# 0          BRONX         77151.0             309.0
# 1       BROOKLYN        168320.0             700.0
# 2      MANHATTAN         75468.0             373.0
# 3         QUEENS        128192.0             573.0
# 4  STATEN ISLAND         18971.0             106.0
# 5        UNKNOWN        243897.0            1373.0

# %%
# Crash Severity by Borough with adjusted title spacing
plt.figure(figsize=(12, 6))
bars = plt.bar(borough_severity['BOROUGH'],
               borough_severity['Total_Injuries'],
               label='Injuries', color='skyblue')
plt.bar(borough_severity['BOROUGH'],
        borough_severity['Total_Fatalities'],
        bottom=borough_severity['Total_Injuries'],
        label='Fatalities', color='salmon')

# Add labels on top of bars
for i, (inj, fat) in enumerate(zip(borough_severity['Total_Injuries'], borough_severity['Total_Fatalities'])):
    total = inj + fat
    pct = (total / borough_severity[['Total_Injuries', 'Total_Fatalities']].sum().sum()) * 100
    plt.text(i, total + 500, f'{total:,} ({pct:.1f}%)', ha='center', fontsize=10, fontweight='bold')

# Title with adjusted padding
plt.title('Crash Severity by Borough (Injuries + Fatalities, % of Total)', pad=20, fontsize=14, fontweight='bold')
plt.ylabel('Number of People')
plt.xticks(rotation=30)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# FINAL VISUALIZATION DASHBOARD
# This will generate all key charts in one go.

plt.style.use('seaborn-v0_8')  # Clean professional style

# ========== 1. Crashes by Year (Trend) ==========
yearly_crashes = df['YEAR'].value_counts().sort_index()

plt.figure(figsize=(10, 5))
plt.plot(yearly_crashes.index, yearly_crashes.values, marker='o', linestyle='-', color='navy')
for i, value in enumerate(yearly_crashes.values):
    plt.text(yearly_crashes.index[i], value + 3000, f'{value:,}', ha='center', fontsize=9, fontweight='bold')

plt.title('NYC Vehicle Collisions by Year (2012–2025)', fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Crashes', fontsize=12)
plt.xticks(yearly_crashes.index, rotation=45)
plt.tight_layout()
plt.show()


# ========== 2. Crashes by Borough ==========
borough_crashes = df['BOROUGH'].value_counts()

plt.figure(figsize=(8, 5))
bars = plt.bar(borough_crashes.index, borough_crashes.values, color='royalblue')
for bar in bars:
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 2000,
             f'{int(bar.get_height()):,}', ha='center', fontsize=9, fontweight='bold')

plt.title('Crashes by Borough', fontsize=16, fontweight='bold')
plt.xlabel('Borough', fontsize=12)
plt.ylabel('Number of Crashes', fontsize=12)
plt.tight_layout()
plt.show()


# ========== 3. Total Injuries vs Fatalities (Log Scale) ==========
total_injuries = df['NUMBER OF PERSONS INJURED'].sum()
total_fatalities = df['NUMBER OF PERSONS KILLED'].sum()

plt.figure(figsize=(6, 5))
plt.bar(['Injured', 'Killed'], [total_injuries, total_fatalities],
        color=['blue', 'red'], log=True)

for i, value in enumerate([total_injuries, total_fatalities]):
    plt.text(i, value + 1000, f'{int(value):,}', ha='center', fontsize=10, fontweight='bold')

plt.title('Total Injuries vs Fatalities (Log Scale)', fontsize=16, fontweight='bold')
plt.ylabel('Number of People (Log Scale)', fontsize=12)
plt.tight_layout()
plt.show()


# ========== 4. Top 10 Contributing Factors ==========
contrib_factors = df['CONTRIBUTING FACTOR VEHICLE 1'].value_counts().head(10)

plt.figure(figsize=(10, 6))
bars = plt.barh(contrib_factors.index, contrib_factors.values, color='orange')
for bar, value in zip(bars, contrib_factors.values):
    plt.text(value + 2000, bar.get_y() + bar.get_height()/2, f'{int(value):,}',
             va='center', fontsize=9, fontweight='bold')

plt.title('Top 10 Contributing Factors', fontsize=16, fontweight='bold')
plt.xlabel('Number of Crashes', fontsize=12)
plt.ylabel('Contributing Factor', fontsize=12)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()


# ========== 5. Top 10 Streets & Cross Streets ==========
# --- Top Streets ---
top_streets = df['ON STREET NAME'].value_counts().head(10)

plt.figure(figsize=(10, 6))
bars = plt.barh(top_streets.index, top_streets.values, color='teal')
for bar, value in zip(bars, top_streets.values):
    plt.text(value + 200, bar.get_y() + bar.get_height()/2, f'{int(value):,}',
             va='center', fontsize=9, fontweight='bold')

plt.title('Top 10 Streets by Crash Count', fontsize=16, fontweight='bold')
plt.xlabel('Number of Crashes', fontsize=12)
plt.ylabel('Street Name', fontsize=12)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# --- Top Cross Streets ---
top_cross = df['CROSS STREET NAME'].value_counts().head(10)

plt.figure(figsize=(10, 6))
bars = plt.barh(top_cross.index, top_cross.values, color='seagreen')
for bar, value in zip(bars, top_cross.values):
    plt.text(value + 200, bar.get_y() + bar.get_height()/2, f'{int(value):,}',
             va='center', fontsize=9, fontweight='bold')

plt.title('Top 10 Cross Streets by Crash Count', fontsize=16, fontweight='bold')
plt.xlabel('Number of Crashes', fontsize=12)
plt.ylabel('Cross Street Name', fontsize=12)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()


# ========== 6. Crash Severity by Borough ==========
borough_severity = df.groupby('BOROUGH').agg(
    Total_Injuries=('NUMBER OF PERSONS INJURED', 'sum'),
    Total_Fatalities=('NUMBER OF PERSONS KILLED', 'sum')
).reset_index()

plt.figure(figsize=(12, 6))
bars = plt.bar(borough_severity['BOROUGH'], borough_severity['Total_Injuries'],
               label='Injuries', color='skyblue')
plt.bar(borough_severity['BOROUGH'], borough_severity['Total_Fatalities'],
        bottom=borough_severity['Total_Injuries'],
        label='Fatalities', color='salmon')

# Add labels
total = borough_severity['Total_Injuries'] + borough_severity['Total_Fatalities']
total_all = total.sum()
for i, value in enumerate(total):
    plt.text(i, total[i] + 2000,
             f'{int(value):,} ({(value/total_all)*100:.1f}%)',
             ha='center', fontsize=9, fontweight='bold')

plt.title('Crash Severity by Borough (Injuries + Fatalities, % of Total)', fontsize=16, fontweight='bold', pad=20)
plt.ylabel('Number of People', fontsize=12)
plt.xticks(rotation=20)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import folium
from folium.plugins import HeatMap

# Filter rows with valid lat/lon
map_data = df[['LATITUDE', 'LONGITUDE']].dropna()

# Sample for performance (optional, you can remove this line)
map_data_sample = map_data.sample(50000, random_state=42)

# Create base map centered on NYC
nyc_map = folium.Map(location=[40.7128, -74.0060], zoom_start=11, tiles='CartoDB positron')

# Add HeatMap layer
HeatMap(data=map_data_sample[['LATITUDE', 'LONGITUDE']].values.tolist(),
        radius=8, blur=10).add_to(nyc_map)

# Save map as HTML (open in browser for screenshot)
nyc_map.save('nyc_crash_heatmap.html')

nyc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
# Enhanced Heatmap with Borough Markers
import folium
from folium.plugins import HeatMap

# Filter rows with valid lat/lon
df_map = df[['LATITUDE', 'LONGITUDE', 'BOROUGH']].dropna()

# Center map on NYC
nyc_map = folium.Map(location=[40.7128, -74.0060], zoom_start=10, tiles='cartodbpositron')

# Add HeatMap
heat_data = list(zip(df_map['LATITUDE'], df_map['LONGITUDE']))
HeatMap(heat_data, radius=8, blur=6).add_to(nyc_map)

# Add markers for each borough
borough_coords = {
    "BRONX": [40.8448, -73.8648],
    "BROOKLYN": [40.6782, -73.9442],
    "MANHATTAN": [40.7831, -73.9712],
    "QUEENS": [40.7282, -73.7949],
    "STATEN ISLAND": [40.5795, -74.1502]
}

for borough, coords in borough_coords.items():
    folium.Marker(coords, popup=borough, icon=folium.Icon(color='blue')).add_to(nyc_map)

# Save to HTML
nyc_map.save('nyc_crashes_heatmap.html')

# %%
# --- 1. Crashes by Year (Trend) ---
plt.figure(figsize=(10, 6))
yearly_counts = df['YEAR'].value_counts().sort_index()

plt.plot(yearly_counts.index, yearly_counts.values, marker='o', color='royalblue', linewidth=2)
for i, v in enumerate(yearly_counts.values):
    plt.text(yearly_counts.index[i], v + 3000, f"{v:,}", ha='center', fontsize=9, fontweight='bold')

plt.title("NYC Vehicle Collisions by Year (2012–2025)", fontsize=16, weight='bold', pad=20)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Number of Crashes", fontsize=12)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# --- 2. Crashes by Borough ---
plt.figure(figsize=(10, 6))
borough_counts = df['BOROUGH'].value_counts()

bars = plt.bar(borough_counts.index, borough_counts.values, color='orange')
for bar, val in zip(bars, borough_counts.values):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 5000,
             f"{val:,}", ha='center', fontsize=9, fontweight='bold')

plt.title("Crashes by Borough", fontsize=16, weight='bold', pad=20)
plt.xlabel("Borough", fontsize=12)
plt.ylabel("Number of Crashes", fontsize=12)
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# --- 3. Total Injuries vs Fatalities (Log Scale) ---
injuries = df['NUMBER OF PERSONS INJURED'].sum()
fatalities = df['NUMBER OF PERSONS KILLED'].sum()

plt.figure(figsize=(7, 6))
bars = plt.bar(['Injured', 'Killed'], [injuries, fatalities],
               color=['blue', 'red'], log=True)

# Add labels
for bar, val in zip(bars, [injuries, fatalities]):
    plt.text(bar.get_x() + bar.get_width()/2, val * 1.05,
             f"{int(val):,}", ha='center', fontsize=10, fontweight='bold')

plt.title("Total Injuries vs Fatalities (Log Scale)", fontsize=16, weight='bold', pad=20)
plt.ylabel("Number of People (Log Scale)", fontsize=12)
plt.tight_layout()
plt.show()

# %%
# --- 4. Top 10 Contributing Factors ---
plt.figure(figsize=(10, 6))
top_factors = df['CONTRIBUTING FACTOR VEHICLE 1'].value_counts().head(10)

bars = plt.barh(top_factors.index[::-1], top_factors.values[::-1], color='orange')
for bar, val in zip(bars, top_factors.values[::-1]):
    plt.text(val + 2000, bar.get_y() + bar.get_height()/2,
             f"{val:,}", va='center', fontsize=9, fontweight='bold')

plt.title("Top 10 Contributing Factors", fontsize=16, weight='bold', pad=20)
plt.xlabel("Number of Crashes", fontsize=12)
plt.tight_layout()
plt.show()

# --- 5. Top 10 Streets & Cross Streets ---
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Streets
top_streets = df['ON STREET NAME'].value_counts().head(10)
bars1 = ax[0].barh(top_streets.index[::-1], top_streets.values[::-1], color='teal')
for bar, val in zip(bars1, top_streets.values[::-1]):
    ax[0].text(val + 200, bar.get_y() + bar.get_height()/2,
               f"{val:,}", va='center', fontsize=9, fontweight='bold')
ax[0].set_title("Top 10 Streets by Crash Count", fontsize=14, weight='bold')
ax[0].set_xlabel("Number of Crashes")

# Cross Streets
top_cross = df['CROSS STREET NAME'].value_counts().head(10)
bars2 = ax[1].barh(top_cross.index[::-1], top_cross.values[::-1], color='seagreen')
for bar, val in zip(bars2, top_cross.values[::-1]):
    ax[1].text(val + 200, bar.get_y() + bar.get_height()/2,
               f"{val:,}", va='center', fontsize=9, fontweight='bold')
ax[1].set_title("Top 10 Cross Streets by Crash Count", fontsize=14, weight='bold')
ax[1].set_xlabel("Number of Crashes")

plt.tight_layout()
plt.show()

# --- 6. Crash Severity by Borough (final polish) ---
plt.figure(figsize=(12, 6))
borough_severity = df.groupby('BOROUGH', as_index=False).agg({
    'NUMBER OF PERSONS INJURED': 'sum',
    'NUMBER OF PERSONS KILLED': 'sum'
}).rename(columns={
    'NUMBER OF PERSONS INJURED': 'Total_Injuries',
    'NUMBER OF PERSONS KILLED': 'Total_Fatalities'
})
borough_severity['Total'] = borough_severity['Total_Injuries'] + borough_severity['Total_Fatalities']
total_all = borough_severity['Total'].sum()

bars = plt.bar(borough_severity['BOROUGH'], borough_severity['Total_Injuries'],
               label='Injuries', color='skyblue')
plt.bar(borough_severity['BOROUGH'], borough_severity['Total_Fatalities'],
        bottom=borough_severity['Total_Injuries'], label='Fatalities', color='salmon')

for i, total in enumerate(borough_severity['Total']):
    percent = (total / total_all) * 100
    plt.text(i, total + 2000, f"{int(total):,} ({percent:.1f}%)",
             ha='center', fontsize=9, fontweight='bold')

plt.title("Crash Severity by Borough (Injuries + Fatalities, % of Total)",
          fontsize=16, weight='bold', pad=20)
plt.xlabel("Borough", fontsize=12)
plt.ylabel("Number of People", fontsize=12)
plt.legend()
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()
